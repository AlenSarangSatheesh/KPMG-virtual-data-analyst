# %%
import pandas as pd

# %%
df = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx' , sheet_name=None)

# %% [markdown]
# # Exploring Tables

# %%
customer_demographic = df['CustomerDemographic']
customer_addresses = df['CustomerAddress']
transactions_data = df['Transactions']
newcustomer_list = df['NewCustomerList']

# %%
customer_demographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases                  DOB  \
# 0                                      93  1953-10-12 00:00:00
# 1                                      81  1980-12-16 00:00:00
# 2                                      61  1954-01-20 00:00:00
# 3                                      33  1961-10-03 00:00:00
# ...

# %%
customer_addresses
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %%
transactions_data
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
newcustomer_list
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#                      DOB                     job_title job_industry_category  \
# ...

# %%
customer_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   object
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
customer_addresses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
transactions_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
newcustomer_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    object
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
customer_demographic.shape
# Out:
# (4000, 13)

# %%
customer_addresses.shape
# Out:
# (3999, 6)

# %%
transactions_data.shape
# Out:
# (20000, 13)

# %%
newcustomer_list.shape
# Out:
# (1000, 23)

# %% [markdown]
# # Duplicate Values

# %%
customer_demographic.duplicated().sum()
# Out:
# 0

# %%
customer_addresses.duplicated().sum()
# Out:
# 0

# %%
transactions_data.duplicated().sum()
# Out:
# 0

# %%
newcustomer_list.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Duplicates not found

# %% [markdown]
# # IsNull Values

# %%
customer_demographic.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
customer_addresses.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
transactions_data.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
newcustomer_list.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %% [markdown]
# Missing Coloumns found

# %% [markdown]
# # Coloumn Exploration

# %%
#How many orders approved
transactions_data['order_status'].value_counts()
# Out:
# order_status
# Approved     19821
# Cancelled      179
# Name: count, dtype: int64

# %%
#List Brands
transactions_data['brand'].value_counts()
# Out:
# brand
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: count, dtype: int64

# %%
#List Job Title of Customers
customer_demographic['job_title'].value_counts()
# Out:
# job_title
# Business Systems Development Analyst    45
# Tax Accountant                          44
# Social Worker                           44
# Internal Auditor                        42
# Recruiting Manager                      41
#                                         ..
# Database Administrator I                 4
# Health Coach I                           3
# Health Coach III                         3
# Research Assistant III                   3
# Developer I                              1
# Name: count, Length: 195, dtype: int64

# %%
#List Job Industry
customer_demographic['job_industry_category'].value_counts()
# Out:
# job_industry_category
# Manufacturing         799
# Financial Services    774
# Health                602
# Retail                358
# Property              267
# IT                    223
# Entertainment         136
# Argiculture           113
# Telecommunications     72
# Name: count, dtype: int64

# %%
#List Country of customers 
newcustomer_list['state'].value_counts()
# Out:
# state
# NSW    506
# VIC    266
# QLD    228
# Name: count, dtype: int64

# %% [markdown]
# # Converting Datatypes

# %%
customer_demographic.dtypes
# Out:
# customer_id                              int64
# first_name                              object
# last_name                               object
# gender                                  object
# past_3_years_bike_related_purchases      int64
# DOB                                     object
# job_title                               object
# job_industry_category                   object
# wealth_segment                          object
# deceased_indicator                      object
# default                                 object
# owns_car                                object
# tenure                                 float64
# dtype: object

# %%
#Converting DoB to date data type from object
customer_demographic['DOB'] = pd.to_datetime(customer_demographic['DOB'])

# %%
#Coverting first sold date to date
transactions_data['product_first_sold_date'] = pd.to_datetime(transactions_data['product_first_sold_date'])

# %%
#Converting DoB to date data type from object
newcustomer_list['DOB'] = pd.to_datetime(newcustomer_list['DOB'])

# %% [markdown]
# # Removing unknown coloumns

# %%
# newcustomer_list table having missing coloumn names
#Removing those coloumns
newcustomer_list = newcustomer_list.drop([ 'Unnamed: 16' ,'Unnamed: 17' , 'Unnamed: 18' , 'Unnamed: 19'], axis = 1 )

# %%
newcustomer_list.dtypes
# Out:
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# owns_car                                       object
# tenure                                          int64
# address                                        object
# postcode                                        int64
# state                                          object
# country                                        object
# property_valuation                              int64
# Unnamed: 20                                     int64
# ...

# %% [markdown]
# # Gender has ' U ' values

# %%
newcustomer_list[newcustomer_list.gender == 'U']
# Out:
#     first_name    last_name gender  past_3_years_bike_related_purchases DOB  \
# 59       Normy     Goodinge      U                                    5 NaT
# 226      Hatti     Carletti      U                                   35 NaT
# 324   Rozamond       Turtle      U                                   69 NaT
# 358      Tamas      Swatman      U                                   65 NaT
# 360      Tracy   Andrejevic      U                                   71 NaT
# 374     Agneta      McAmish      U                                   66 NaT
# 434      Gregg      Aimeric      U                                   52 NaT
# 439      Johna       Bunker      U                                   93 NaT
# 574    Harlene         Nono      U                                   69 NaT
# 598   Gerianne       Kaysor      U                                   15 NaT
# 664     Chicky      Sinclar      U                                   43 NaT
# ...

# %%
#default coloumn has correpted values
customer_demographic['default'].head()
# Out:
# 0                                                   "'
# 1                         <script>alert('hi')</script>
# 2                                  2018-02-01 00:00:00
# 3    () { _; } >_[$($())] { touch /tmp/blns.shellsh...
# 4                                                  NIL
# Name: default, dtype: object

# %% [markdown]
# # Incomplete gender in customer_demographic

# %%
customer_demographic[customer_demographic.gender == 'F' ]
# Out:
#     customer_id first_name last_name gender  \
# 56           57       Abba   Masedon      M
#
#     past_3_years_bike_related_purchases        DOB              job_title  \
# 56                                   87 1988-06-13  Chief Design Engineer
#
#    job_industry_category wealth_segment deceased_indicator default owns_car  \
# 56                   NaN  Mass Customer                  N     100      Yes
#
#     tenure
# 56    13.0

# %%
customer_demographic[customer_demographic.gender == 'M' ]
# Out:
#     customer_id first_name last_name gender  \
# 56           57       Abba   Masedon      M
#
#     past_3_years_bike_related_purchases        DOB              job_title  \
# 56                                   87 1988-06-13  Chief Design Engineer
#
#    job_industry_category wealth_segment deceased_indicator default owns_car  \
# 56                   NaN  Mass Customer                  N     100      Yes
#
#     tenure
# 56    13.0

# %%
customer_demographic[customer_demographic.gender == 'Femal' ]
# Out:
#     customer_id first_name last_name gender  \
# 53           54    Loralyn    Wonfor  Femal
#
#     past_3_years_bike_related_purchases        DOB        job_title  \
# 53                                    2 1966-07-24  Sales Associate
#
#    job_industry_category wealth_segment deceased_indicator default owns_car  \
# 53              Property  Mass Customer                  N    -0.5      Yes
#
#     tenure
# 53    18.0

# %% [markdown]
# # Irrelavant coloumn

# %%
customer_demographic['default']
# Out:
# 0                                                      "'
# 1                            <script>alert('hi')</script>
# 2                                     2018-02-01 00:00:00
# 3       () { _; } >_[$($())] { touch /tmp/blns.shellsh...
# 4                                                     NIL
#                               ...
# 3995                                                 -100
# 3996                                             â¦testâ§
# 3997                                                  NaN
# 3998                               Â¡â¢Â£Â¢âÂ§Â¶â¢ÂªÂºââ
# 3999                                                  0/0
# Name: default, Length: 4000, dtype: object
